# %%
# Import Necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
# Import csv file

data = pd.read_csv("data/merged_copy_14cols_new_data.csv")
data
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1      53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2      70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3      61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4      62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 8360   62    1   1       NaN  139.0  0.0      1.0      NaN    NaN      NaN
# 8361   55    1   4     122.0  223.0  1.0      1.0    100.0    0.0      0.0
# 8362   58    1   4       NaN  385.0  1.0      2.0      NaN    NaN      NaN
# 8363   62    1   2     120.0  254.0  0.0      2.0     93.0    1.0      0.0
# 8364   47    1   4     150.0  226.0  0.0      0.0     98.0    1.0      1.5
#
#       slope   ca  thal  target
# 0       2.0  2.0   3.0       0
# ...

# %%
len(data)
# Out:
# 8365

# %%
data.isna().sum().sum()
# Out:
# 1805

# %%
data_temp = data.copy()

# %%
data_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8365 entries, 0 to 8364
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       8365 non-null   int64
#  1   sex       8365 non-null   int64
#  2   cp        8365 non-null   int64
#  3   trestbps  8298 non-null   float64
#  4   chol      8333 non-null   float64
#  5   fbs       8276 non-null   float64
#  6   restecg   8363 non-null   float64
#  7   thalach   8300 non-null   float64
#  8   exang     8310 non-null   float64
#  9   oldpeak   8303 non-null   float64
#  10  slope     8056 non-null   float64
#  11  ca        7740 non-null   float64
#  12  thal      7866 non-null   float64
#  13  target    8365 non-null   int64
# dtypes: float64(10), int64(4)
# memory usage: 915.0 KB

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps         chol  \
# count  8365.000000  8365.000000  8365.000000  8298.000000  8333.000000
# mean     54.326240     0.696234     1.928033   131.694505   241.523221
# std       9.099079     0.459910     1.391401    17.732850    62.507997
# min      28.000000     0.000000     0.000000     0.000000     0.000000
# 25%      48.000000     0.000000     1.000000   120.000000   209.000000
# 50%      55.000000     1.000000     2.000000   130.000000   240.000000
# 75%      61.000000     1.000000     3.000000   140.000000   275.000000
# max      77.000000     1.000000     4.000000   200.000000   603.000000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  8276.000000  8363.000000  8300.000000  8310.000000  8303.000000
# mean      0.149831     0.686117   148.259277     0.335860     1.033193
# std       0.356927     0.768074    23.512168     0.472319     1.157479
# ...

# %%
pd.crosstab(data_temp["age"], data_temp["target"])
# Out:
# target    0    1
# age
# 28        1    0
# 29       12   17
# 30        1    0
# 31        1    1
# 32        3    1
# 33        1    1
# 34       23   32
# 35       56   56
# 36        4    2
# 37       28   31
# 38       26   54
# 39       56   58
# 40       50   39
# 41      113  154
# 42       95  119
# 43      107  108
# 44      132  156
# 45       99  112
# 46       96  100
# 47       68   77
# 48      101  102
# 49       72   74
# 50       92  101
# 51      148  181
# 52      159  187
# 53      101  123
# 54      214  231
# 55      128  115
# 56      154  158
# 57      237  216
# 58      267  246
# 59      200  177
# 60      161  152
# 61      133  103
# 62      157  150
# 63      133  119
# 64      126  143
# 65      108  111
# 66       90   98
# 67      128  110
# 68       52   53
# 69       36   49
# 70       59   48
# 71       30   51
# 72        1    3
# 73        0    1
# 74       11   20
# 75        1    2
# 76       10   16
# 77       15   11

# %%
import seaborn as sns

corr_matrix = data_temp.corr()

fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(corr_matrix, annot=True, ax=ax, cmap="YlGnBu");

# %%
data_temp.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1   53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2   70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3   61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 1    0.0  0.0   3.0       0
# 2    0.0  0.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0

# %%
plt.scatter(data_temp["age"], data_temp["chol"])

# %%
data_temp.dropna(inplace=True)

# %%
data_temp
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1      53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2      70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3      61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4      62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 8040   68    1   4     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 8041   57    1   4     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 8042   57    0   2     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 8192   56    1   4     120.0  100.0  0.0      0.0    120.0    1.0      1.5
# 8364   47    1   4     150.0  226.0  0.0      0.0     98.0    1.0      1.5
#
#       slope   ca  thal  target
# 0       2.0  2.0   3.0       0
# ...

# %%
data_temp.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data_temp[data_temp["thalach"] > 200]
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 60     29    1   1     130.0  204.0  0.0      0.0    202.0    0.0      0.0
# 64     29    1   1     130.0  204.0  0.0      0.0    202.0    0.0      0.0
# 118    29    1   1     130.0  204.0  0.0      0.0    202.0    0.0      0.0
# 668    29    1   1     130.0  204.0  0.0      0.0    202.0    0.0      0.0
# 1096   29    1   1     130.0  204.0  0.0      2.0    202.0    0.0      0.0
# 1394   29    1   1     130.0  204.0  0.0      0.0    202.0    0.0      0.0
# 1697   29    1   1     130.0  204.0  0.0      0.0    202.0    0.0      0.0
# 1999   29    1   1     130.0  204.0  0.0      2.0    202.0    0.0      0.0
# 2297   29    1   1     130.0  204.0  0.0      0.0    202.0    0.0      0.0
# 2600   29    1   1     130.0  204.0  0.0      0.0    202.0    0.0      0.0
# 2903   29    1   1     130.0  204.0  0.0      0.0    202.0    0.0      0.0
# ...

# %%
data_temp.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1   53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2   70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3   61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 1    0.0  0.0   3.0       0
# 2    0.0  0.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0

# %% [markdown]
# **Majority of the data's slope is 2(flat)**

# %%
len(data_temp[data_temp["slope"] == 2])
# Out:
# 3223

# %% [markdown]
# **cp: chest pain type**
# - Value 1: typical angina = obtained (1414)
# - Value 2: atypical angina = obtained(1809)
# - Value 3: non-anginal pain = obtained(1568)
# - Value 4: asymptomatic = obtained(1061)

# %%
len(data_temp[data_temp["cp"] == 4])
# Out:
# 1061

# %%
pd.plotting.scatter_matrix(data_temp, figsize=(20,20));

# %%
data_temp.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1   53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2   70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3   61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 1    0.0  0.0   3.0       0
# 2    0.0  0.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0

# %%
data_temp.slope.dtype
# Out:
# dtype('float64')

# %%
data_temp["trestbps"].sum()
# Out:
# 1013001.0

# %%
corr_slope = pd.crosstab(data_temp["slope"], data_temp["target"])

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr_slope, cmap="YlGnBu", annot=True);

# %%
data_temp.nunique()
# Out:
# age          41
# sex           2
# cp            5
# trestbps     50
# chol        153
# fbs           2
# restecg       3
# thalach      92
# exang         2
# oldpeak      40
# slope         4
# ca            5
# thal          6
# target        2
# dtype: int64

# %%
data_temp['ca'].unique()
# Out:
# array([2., 0., 1., 3., 4.])

# %%
data_temp.slope.value_counts()
# Out:
# 2.0    3223
# 1.0    3044
# 0.0     819
# 3.0     609
# Name: slope, dtype: int64

# %%
data_temp.loc[data_temp["slope"]==0, "slope"] = np.NaN

# %%
data_temp["slope"].unique()
# Out:
# array([ 2., nan,  1.,  3.])

# %%
data_temp.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps      0
# chol          0
# fbs           0
# restecg       0
# thalach       0
# exang         0
# oldpeak       0
# slope       819
# ca            0
# thal          0
# target        0
# dtype: int64

# %%
import missingno as msno

msno.matrix(data_temp);

# %%
data_temp.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1   53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2   70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3   61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 1    NaN  0.0   3.0       0
# 2    NaN  0.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0

# %%
data_temp.loc[data_temp["cp"] == 0, "cp"] = np.NaN

# %%
data_temp.isna().sum()
# Out:
# age            0
# sex            0
# cp          1843
# trestbps       0
# chol           0
# fbs            0
# restecg        0
# thalach        0
# exang          0
# oldpeak        0
# slope        819
# ca             0
# thal           0
# target         0
# dtype: int64

# %%
msno.matrix(data_temp);

# %%
data_temp = data_temp.fillna(data_temp.median())

# %%
data_temp.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
duplicated = data_temp.duplicated().sum()

if duplicated == 0:
    print(f"Duplicates Rows in Dataset are: {duplicated}")
else:
    print(f"Dataset has no duplicate values")
# Out:
# Dataset has no duplicate values

# %%
duplicated = data_temp[data_temp.duplicated(keep=False)]
duplicated.head()
# Out:
#    age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1  2.0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1   53    1  2.0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2   70    1  2.0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3   61    1  2.0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0  2.0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 1    2.0  0.0   3.0       0
# 2    2.0  0.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0

# %%
data_temp.describe()
# Out:
#                age          sex           cp     trestbps         chol  \
# count  7695.000000  7695.000000  7695.000000  7695.000000  7695.000000
# mean     54.445354     0.684730     2.295776   131.644055   246.694737
# std       9.068399     0.464653     0.922864    17.616131    51.759057
# min      29.000000     0.000000     1.000000    94.000000   100.000000
# 25%      48.000000     0.000000     2.000000   120.000000   211.000000
# 50%      56.000000     1.000000     2.000000   130.000000   241.000000
# 75%      61.000000     1.000000     3.000000   140.000000   275.000000
# max      77.000000     1.000000     4.000000   200.000000   564.000000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  7695.000000  7695.000000  7695.000000  7695.000000  7695.000000
# mean      0.146719     0.707472   149.500195     0.329825     1.055569
# std       0.353848     0.775278    22.919553     0.470180     1.165620
# ...

# %%
data_temp["target"] = data_temp["target"].replace({1: "Disease", 0: "No Disease"})
data_temp["sex"] = data_temp.sex.replace({1: "Male", 0: "Female"})
data_temp["cp"] = data_temp.cp.replace({1: "Typical Angina", 2: "Atypical Angina", 3: "Non-Anginal Pain", 4: "Asymptomatic"})
data_temp["fbs"] = data_temp.fbs.replace({1: "True", 0: "False"})
data_temp["slope"] = data_temp.slope.replace({1: "Upsloping", 2: "Flar", 3: "Downsloping"})
data_temp["thal"] = data_temp.thal.replace({1: "Normal", 2: "Fixed Defect", 3: "Reversible Defect"})

# %%
data_temp.plot(kind="box", subplots=True, layout=(2,7), sharex=False, sharey=False, figsize=(20,10), color="green");

# %% [markdown]
# # Outliers
#
# - In data analysis, outliers are data points that are significantly different from other data points in a dataset. Outliers are observations that fall far away from the bulk of the data points, and they can have a significant impact on statistical analysis, modeling, and machine learning algorithms.
#
# - Outliers can arise due to various reasons such as measurement or recording errors, data entry errors, or natural variation in the data. Outliers can also occur due to unusual events, anomalies, or extreme values in the data.
#
# - It is important to identify and handle outliers appropriately in data analysis. Outliers can distort statistical measures such as mean and standard deviation and can affect the results of data analysis, making it difficult to draw meaningful insights from the data.
#
# - There are various methods to detect and handle outliers, such as visual inspection of the data using box plots or scatter plots, statistical methods such as z-score or IQR (Interquartile Range), or machine learning methods such as clustering or anomaly detection. The method used to handle outliers will depend on the type of data, the research question, and the context of the analysis.

# %%
# define continuous variable and plot

continous_features = ["age", "trestbps", "chol", "thalach", "oldpeak"]

def outliers(data_out, drop = False):
    for each_feature in data_out.columns:
        feature_data = data_out[each_feature]
        Q1 = np.percentile(feature_data, 25) # 25th percentile
        Q3 = np.percentile(feature_data, 75) # 75th percentile
        IQR = Q3 - Q1 # Interquartile range
        outlier_step = 1.5 * IQR # outlier step
        outliers = feature_data[~((feature_data >= Q1 - outlier_step) & (feature_data <= Q3 + outlier_step))].index.tolist()
        if not drop:
            print(f"Feature {each_feature} has {len(outliers)} outliers")
        if drop:
            data_temp.drop(outliers, inplace=True, errors="ignore")
            print(f"Outliers from {each_feature} feature has been removed")

outliers(data_temp[continous_features])
# Out:
# Feature age has 0 outliers
# Feature trestbps has 231 outliers
# Feature chol has 128 outliers
# Feature thalach has 27 outliers
# Feature oldpeak has 128 outliers

# %%
outliers(data_temp[continous_features], drop=True)
# Out:
# Outliers from age feature has been removed
# Outliers from trestbps feature has been removed
# Outliers from chol feature has been removed
# Outliers from thalach feature has been removed
# Outliers from oldpeak feature has been removed

# %%
data_temp.head()
# Out:
#    age     sex               cp  trestbps   chol    fbs  restecg  thalach  \
# 0   52    Male  Atypical Angina     125.0  212.0  False      1.0    168.0
# 1   53    Male  Atypical Angina     140.0  203.0   True      0.0    155.0
# 2   70    Male  Atypical Angina     145.0  174.0  False      1.0    125.0
# 3   61    Male  Atypical Angina     148.0  203.0  False      1.0    161.0
# 4   62  Female  Atypical Angina     138.0  294.0   True      1.0    106.0
#
#    exang  oldpeak      slope   ca               thal      target
# 0    0.0      1.0       Flar  2.0  Reversible Defect  No Disease
# 1    1.0      3.1       Flar  0.0  Reversible Defect  No Disease
# 2    1.0      2.6       Flar  0.0  Reversible Defect  No Disease
# 3    0.0      0.0       Flar  1.0  Reversible Defect  No Disease
# 4    0.0      1.9  Upsloping  3.0       Fixed Defect  No Disease

# %% [markdown]
# ## Distribution and Relationship
#
# ### a) target variable distribution

# %%
print(data_temp["target"].value_counts())

# data_temp["target"].value_counts().plot(kind="bar")

fig, ax = plt.subplots(figsize=(5,4))

name = ["Disease", "No Disease"]

ax = data_temp.target.value_counts().plot(kind="bar")

ax.set_title("Heart Disease Classes", fontsize=13, weight="bold")
ax.set_xticklabels(name, rotation=0)

# to calculate the percentage of each class

totals = []

for i in ax.patches:
    totals.append(i.get_height())
total = sum(totals)

for i in ax.patches:
    ax.text(i.get_x()+0.9, i.get_height()-50, \
             str(round((i.get_height()/total)*100, 2)) + "%",
             fontsize=12, color="white", weight="bold")

plt.tight_layout()
# Out:
# Disease       3660
# No Disease    3546
# Name: target, dtype: int64

# %% [markdown]
# ### b) Age Variable Distribution

# %%
fig, ax = plt.subplots()

ax.hist(data_temp["age"])
plt.title("Age Distribution")
plt.show()

# %%
# Analyze distribution in age in range 10
print(data_temp.age.value_counts()[:10])

sns.barplot(x=data_temp.age.value_counts()[:10].index, y=data_temp.age.value_counts()[:10].values, palette="pastel")
plt.xlabel("Age")
plt.ylabel("Age Distribution")
# Out:
# 58    458
# 57    428
# 54    385
# 59    304
# 60    293
# 52    282
# 44    280
# 51    279
# 41    253
# 56    233
# Name: age, dtype: int64
# Text(0, 0.5, 'Age Distribution')

# %% [markdown]
# **from the above plot we can see that most of the patients are in the age between 50 to 60**

# %%
print(min(data_temp["age"]))
print(max(data_temp["age"]))
print(data_temp["age"].mean())
# Out:
# 29
# 77
# 54.0721620871496

# %% [markdown]
# ### c) gender distribution to target variable

# %%
# fig, ax = plt.subplots(figsize=(10,5))

# name = data_temp["sex"]

# ax = sns.countplot(x="sex", hue="target", data=data_temp, palette="pastel")
# ax.set_title("Sex Distribution according to Target", fontsize=13, weight="bold")
# ax.set_xticklabels (name, rotation=0)


# totals = []

# for i in ax.patches:
#     totals.append(i.get_height())
# total = sum(totals)

# # for i in ax.patches:
# #     ax.text(i.get_x()+0.1, i.get_height()-15, \
# #                 str(round((i.get_height()/total)*100, 2)) + "%",
# #                 fontsize=12, color="white", weight="bold")

# plt.tight_layout()
